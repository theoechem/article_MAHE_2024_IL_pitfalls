# %%
from unitpackage.cv.cv_collection import CVCollection

# %%
local_db = CVCollection.from_local('../data/figures/')
local_db
# Out:
# [CVEntry('fig_1_a_black'), CVEntry('fig_1_a_red'), CVEntry('fig_1_b_black'), CVEntry('fig_1_b_red'), CVEntry('fig_2_a_black_dotted'), CVEntry('fig_2_a_black_solid'), CVEntry('fig_2_b_black_dotted'), CVEntry('fig_2_b_black_solid'), CVEntry('fig_4_a_black_dotted'), CVEntry('fig_4_a_blue_solid'), CVEntry('fig_4_a_purple_solid'), CVEntry('fig_4_a_red_solid'), CVEntry('fig_4_b_black_dotted'), CVEntry('fig_4_b_blue_solid'), CVEntry('fig_4_b_purple_solid'), CVEntry('fig_4_b_red_solid'), CVEntry('fig_s1_a_black_dotted'), CVEntry('fig_s1_a_black_solid'), CVEntry('fig_s1_b_black_dotted'), CVEntry('fig_s1_b_black_solid'), CVEntry('fig_s1_c_black_dotted'), CVEntry('fig_s1_c_black_solid'), CVEntry('fig_s1_d_black_dotted'), CVEntry('fig_s1_d_black_solid'), CVEntry('fig_s1_e_black_dotted'), CVEntry('fig_s1_e_black_solid')]

# %%
local_db.describe()
# Out:
# Entry with name fig_1_a_black has no bibliography.
# Entry with name fig_1_a_red has no bibliography.
# Entry with name fig_1_b_black has no bibliography.
# Entry with name fig_1_b_red has no bibliography.
# Entry with name fig_2_a_black_dotted has no bibliography.
# Entry with name fig_2_a_black_solid has no bibliography.
# Entry with name fig_2_b_black_dotted has no bibliography.
# Entry with name fig_2_b_black_solid has no bibliography.
# Entry with name fig_4_a_black_dotted has no bibliography.
# Entry with name fig_4_a_blue_solid has no bibliography.
# Entry with name fig_4_a_purple_solid has no bibliography.
# Entry with name fig_4_a_red_solid has no bibliography.
# Entry with name fig_4_b_black_dotted has no bibliography.
# Entry with name fig_4_b_blue_solid has no bibliography.
# Entry with name fig_4_b_purple_solid has no bibliography.
# Entry with name fig_4_b_red_solid has no bibliography.
# Entry with name fig_s1_a_black_dotted has no bibliography.
# ...

# %%
fig2a_b_dot = local_db['fig_2_a_black_dotted']
fig2a_b_dot.system.electrolyte.components
# Out:
# [{'name': 'MPPi-TFSI', 'proportion': {'unit': 'volume percent', 'value': 100}, 'source': {'supplier': 'IoLiTec', 'purity': {'grade': '>99%'}}, 'type': 'solvent', 'purchased': '2021-05-21'},
#  {'name': 'water', 'proportion': {'unit': 'ppm', 'value': 75, 'description': 'lower equal'}, 'type': 'impurity'}]

# %%
fig2a_b_dot.plot()

# %%
fig2a_b_dot.system.electrodes
# Out:
# [{'name': 'CE', 'function': 'counter electrode', 'crystallographic orientation': 'poly', 'material': 'Pt', 'source': {'manufacturer': 'MaTecK GmbH'}, 'shape': {'type': 'wire'}, 'purity': {'value': 99.99, 'unit': 'pct'}},
#  {'name': 'REF', 'function': 'reference electrode', 'redox system': 'Zn/Zn[TFSI]2', 'source': {'manufacturer': 'Home made', 'url': 'https://onlinelibrary.wiley.com/doi/full/10.1002/ange.202105871'}},
#  {'name': 'WE', 'function': 'working electrode', 'crystallographic orientation': '111', 'material': 'Au', 'preparation procedure': {'description': ['Annealed for 2h at 960°C in air in a muffle furnace']}, 'shape': {'diameter': {'unit': 'mm', 'value': 12}, 'type': 'disk'}, 'source': {'manufacturer': 'MaTecK GmbH'}}]
